# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti612/coursera/blob/main/NGRAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python code to create unigram and bigrams from the given text using NLTK.**

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# ...

# %%
from nltk import ngrams
sentence = input("Enter the sentence: ")
n = int(input("Enter the value of n: "))
n_grams = ngrams(sentence.split(), n)
for grams in n_grams:
    print(grams)
# Out:
# Enter the sentence: London is the capital and largest city of England and the United Kingdom, with a population of just under 9 million. It stands on the River Thames in south-east England at the head of a 50-mile (80 km) estuary down to the North Sea, and has been a major settlement for two millennia. The City of London, its ancient core and financial centre, was founded by the Romans as Londinium and retains its medieval boundaries.The City of Westminster, to the west of the City of London, has for centuries hosted the national government and parliament. Since the 19th century, the name "London" has also referred to the metropolis around this core, historically split between the counties of Middlesex, Essex, Surrey, Kent, and Hertfordshire,[12] which since 1965 has largely comprised Greater London, which is governed by 33 local authorities and the Greater London Authority
# Enter the value of n: 1
# ('London',)
# ('is',)
# ('the',)
# ('capital',)
# ('and',)
# ('largest',)
# ...

# %%
from nltk import ngrams
sentence = input("Enter the sentence: ")
n = int(input("Enter the value of n: "))
n_grams = ngrams(sentence.split(), n)
for grams in n_grams:
    print(grams)
# Out:
# Enter the sentence: London is the capital and largest city of England and the United Kingdom, with a population of just under 9 million. It stands on the River Thames in south-east England at the head of a 50-mile (80 km) estuary down to the North Sea, and has been a major settlement for two millennia. The City of London, its ancient core and financial centre, was founded by the Romans as Londinium and retains its medieval boundaries.The City of Westminster, to the west of the City of London, has for centuries hosted the national government and parliament. Since the 19th century, the name "London" has also referred to the metropolis around this core, historically split between the counties of Middlesex, Essex, Surrey, Kent, and Hertfordshire,[12] which since 1965 has largely comprised Greater London, which is governed by 33 local authorities and the Greater London Authority
# Enter the value of n: 2
# ('London', 'is')
# ('is', 'the')
# ('the', 'capital')
# ('capital', 'and')
# ...

# %% [markdown]
# **Python code to create unigram and bigrams from the given text  Using GPT3 model(ChatGPT).**

# %%
pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import openai as ai

# Get the key from an environment variable on the machine it is running on
ai.api_key = os.environ.get("OPENAI_API_KEY")

# %%
import os
import openai

openai.api_key = "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"
response = openai.Completion.create(
  model="code-davinci-002",
  prompt="# Python 3 \ndef remove_common_prefix(x, prefix, ws_prefix): \n    x[\"completion\"] = x[\"completion\"].str[len(prefix) :] \n    if ws_prefix: \n        # keep the single whitespace as prefix \n        x[\"completion\"] = \" \" + x[\"completion\"] \nreturn x \n\n# Explanation of what the code does\n\n#",
  temperature=0,
  max_tokens=64,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)

# %%
def generate_gpt3_response(user_text, print_output=False):
    """
    Query OpenAI GPT-3 for the specific key and get back a response
    :type user_text: str the user's text to query for
    :type print_output: boolean whether or not to print the raw output JSON
    """
    completions = ai.Completion.create(
        engine='text-davinci-003',  # Determines the quality, speed, and cost.
        temperature=0.5,            # Level of creativity in the response
        prompt=user_text,           # What the user typed in
        max_tokens=100,             # Maximum tokens in the prompt AND response
        n=1,                        # The number of completions to generate
        stop=None,                  # An optional setting to control response generation
    )

    # Displaying the output can be helpful if things go wrong
    if print_output:
        print(completions)

    # Return the first choice's text
    return completions.choices[0].text

# %%
models = ai.Model.list()

for model in models.data:
    print(model.id)
# Out:
# babbage
# davinci
# text-embedding-ada-002
# babbage-code-search-code
# text-similarity-babbage-001
# text-davinci-001
# ada
# curie-instruct-beta
# babbage-code-search-text
# babbage-similarity
# curie-search-query
# code-search-babbage-text-001
# code-cushman-001
# code-search-babbage-code-001
# audio-transcribe-deprecated
# text-ada-001
# text-similarity-ada-001
# text-davinci-insert-002
# ada-code-search-code
# ada-similarity
# code-search-ada-text-001
# text-search-ada-query-001
# text-curie-001
# text-davinci-edit-001
# davinci-search-document
# ada-code-search-text
# text-search-ada-doc-001
# code-davinci-edit-001
# davinci-instruct-beta
# text-similarity-curie-001
# code-search-ada-code-001
# ada-search-query
# text-search-davinci-query-001
# code-davinci-002
# text-davinci-003
# davinci-search-query
# text-davinci-insert-001
# babbage-search-document
# ada-search-document
# text-search-babbage-doc-001
# text-davinci-002
# text-search-curie-doc-001
# ...

# %%
if __name__ == '__main__':
    prompt = 'London is the capital and largest city of England and the United Kingdom, with a population of just under 9 million. It stands on the River Thames in south-east England at the head of a 50-mile (80 km) estuary down to the North Sea, and has been a major settlement for two millennia. The City of London, its ancient core and financial centre, was founded by the Romans as Londinium and retains its medieval boundaries.The City of Westminster, to the west of the City of London, has for centuries hosted the national government and parliament. Since the 19th century, the name "London" has also referred to the metropolis around this core, historically split between the counties of Middlesex, Essex, Surrey, Kent, and Hertfordshire,[12] which since 1965 has largely comprised Greater London, which is governed by 33 local authorities and the Greater London Authority'
    response = generate_gpt3_response(prompt)
    
    print(response)
# Out:
# .

# %%
import openai
import re

openai.api_key = "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"

def generate_ngrams(text, n):
    """
    Generate n-grams from input text.
    """
    response = openai.Completion.create(
      engine="davinci",
      prompt=f"Create {n}-grams from the following text: {text}",
      max_tokens=1024,
      n=1,
      stop=None,
      temperature=0.7,
    )
    result = response.choices[0].text
    return re.findall(r'\w+', result)

text = 'London is the capital and largest city of England and the United Kingdom, with a population of just under 9 million. It stands on the River Thames in south-east England at the head of a 50-mile (80 km) estuary down to the North Sea, and has been a major settlement for two millennia. The City of London, its ancient core and financial centre, was founded by the Romans as Londinium and retains its medieval boundaries.The City of Westminster, to the west of the City of London, has for centuries hosted the national government and parliament. Since the 19th century, the name "London" has also referred to the metropolis around this core, historically split between the counties of Middlesex, Essex, Surrey, Kent, and Hertfordshire,[12] which since 1965 has largely comprised Greater London, which is governed by 33 local authorities and the Greater London Authority'
unigrams = generate_ngrams(text, 1)
bigrams = generate_ngrams(text, 2)

print("Unigrams:", unigrams)
print("Bigrams:", bigrams)
# Out:
# Unigrams: ['Until', 'the', 'creation', 'of', 'Greater', 'London', 'in', '1965', 'the', 'City', 'of', 'London', 'was', 'also', 'the', 'civil', 'parish', 'within', 'the', 'County', 'of', 'London', 'The', 'local', 'authority', 'for', 'the', 'City', 'namely', 'the', 'City', 'of', 'London', 'Corporation', 'is', 'unique', 'in', 'the', 'British', 'municipal', 'system', 'and', 'operates', 'like', 'a', 'local', 'council', 'within', 'the', 'city', 'but', 'is', 'independent', 'of', 'the', 'county', 'council', 'and', 'is', 'not', 'responsible', 'for', 'services', 'in', 'the', 'rest', 'of', 'London', 'including', 'the', 'outer', 'boroughs', 'The', 'City', 'has', 'a', 'resident', 'population', 'of', 'about', '7', '000', 'but', 'over', '300', '000', 'people', 'commute', 'to', 'and', 'work', 'there', 'It', 'is', 'a', 'major', 'financial', 'centre', 'and', 'has', 'the', 'head', 'offices', 'of', 'many', 'of', 'the', 'world', 's', 'largest', 'investment', 'banks', 'and', 'insurance', 'companies', 'It',
# ...

# %% [markdown]
# **Python code to  implement Laplace smoothing for an n-gram model using the NLTK library in Python:**

# %%
len(text1)
# Out:
# 260819

# %%
from nltk.tag.tnt import FreqDist
fdist1 = FreqDist(text1)
fdist1
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
fdist1 = FreqDist(text1);

# %%
top25 = fdist1.most_common(25)

# %%
bigrams = (tuple(nltk.bigrams(text1,pad_left=True, pad_right=True)))

# %%
bigr = nltk.bigrams(text1,pad_left=True, pad_right=True)

# %%
freq_dist = nltk.FreqDist(bigr)
freq_dist
# Out:
# FreqDist({(',', 'and'): 2607, ('of', 'the'): 1847, ("'", 's'): 1737, ('in', 'the'): 1120, (',', 'the'): 908, (';', 'and'): 853, ('to', 'the'): 712, ('.', 'But'): 596, (',', 'that'): 584, ('.', '"'): 557, ...})

# %%
frequencyDist = nltk.ConditionalFreqDist(bigrams)
frequencyDist
# Out:
# <ConditionalFreqDist with 19318 conditions>

# %%
probabilityDist = nltk.ConditionalProbDist(frequencyDist, nltk.LaplaceProbDist)

# %%
for i in probabilityDist.keys():
 for j in probabilityDist[i].samples():
        print ('{0}'.format(i) + " " + '{0}'.format(j) + " " + '{0}'.format(probabilityDist[i].prob(j)))
# Out:
# Streaming output truncated to the last 5000 lines.
# corroded in 0.3333333333333333
# healed around 1.0
# denote their 0.5
# denote his 0.5
# ulceration alluded 1.0
# rummaged out 1.0
# cabinet there 1.0
# discoveries , 1.0
# unprecedentedly dragged 1.0
# ordering of 1.0
# resolutely , 0.5
# resolutely manhandle 0.5
# locking arms 0.5
# locking them 0.5
# gabled roof 1.0
# gasped . 1.0
# inlayings of 1.0
# cabins were 1.0
# dislocation . 1.0
# crows were 0.5
# crows ' 0.5
# adrift from 0.2727272727272727
# adrift ; 0.18181818181818182
# adrift ?" 0.18181818181818182
# adrift and 0.18181818181818182
# adrift , 0.18181818181818182
# timberheads ; 1.0
# ponderosity seemed 1.0
# sparks , 0.5
# sparks in 0.5
# Usually the 1.0
# pads of 1.0
# aspirations , 1.0
# flush and 1.0
# incumbrance the 1.0
# lapse of 1.0
# Gases are 1.0
# generated in 1.0
# balloon . 1.0
# Bays of 1.0
# buoys to 0.5
# buoys out 0.5
# uncapturable whales 1.0
# unskilful fishermen 1.0
# Backs , 1.0
# Dericks , 1.0
# ...

# %%
probabilityDist.conditions()
# Out:
# [None,
#  '[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  'body',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'grammars',
#  'with',
#  'queer',
#  'handkerchief',
#  'mockingly',
#  'embellished',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'known',
#  'nations',
#  'world',
#  'loved',
#  'dust',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'mortality',
#  '"',
#  'While',
#  'you',
#  'take',
#  'hand',
#  'school',
#  'others',
#  'teach',
#  'them',
#  'what',
#  'name',
#  'whale',
#  '-',
#  'fish',
#  'is',
#  'be',
#  'called',
#  'our',
#  'tongue',
#  'leaving',
#  'out',
#  'through',
# ...

# %%
laplaceProbabilityDist = nltk.LaplaceProbDist(freq_dist, bins=freq_dist.N())

# %%
bins=freq_dist.B()
bins
# Out:
# 118750

# %%
samples = laplaceProbabilityDist.samples()

# %%
listOfSamples = list(laplaceProbabilityDist.samples())

# %%
laplaceProbabilityDist.max()
# Out:
# (',', 'and')

# %%
(',', 'and') in laplaceProbabilityDist.samples()
# Out:
# True

# %%
d = dict(laplaceProbabilityDist.samples())

# %%
d['s']
# Out:
# 'disappearance'

# %%
laplaceProbabilityDist
# Out:
# <LaplaceProbDist based on 260820 samples>

# %%
from sklearn.feature_extraction.text import CountVectorizer 
vectorizer = CountVectorizer(ngram_range=(2,2))
analyzer = vectorizer.build_analyzer()
analyzer(str(list(text1)))
# Out:
# ['moby dick',
#  'dick by',
#  'by herman',
#  'herman melville',
#  'melville 1851',
#  '1851 etymology',
#  'etymology supplied',
#  'supplied by',
#  'by late',
#  'late consumptive',
#  'consumptive usher',
#  'usher to',
#  'to grammar',
#  'grammar school',
#  'school the',
#  'the pale',
#  'pale usher',
#  'usher threadbare',
#  'threadbare in',
#  'in coat',
#  'coat heart',
#  'heart body',
#  'body and',
#  'and brain',
#  'brain see',
#  'see him',
#  'him now',
#  'now he',
#  'he was',
#  'was ever',
#  'ever dusting',
#  'dusting his',
#  'his old',
#  'old lexicons',
#  'lexicons and',
#  'and grammars',
#  'grammars with',
#  'with queer',
#  'queer handkerchief',
#  'handkerchief mockingly',
#  'mockingly embellished',
#  'embellished with',
#  'with all',
#  'all the',
#  'the gay',
#  'gay flags',
#  'flags of',
#  'of all',
#  'all the',
#  'the known',
#  'known nations',
#  'nations of',
#  'of the',
#  'the world',
#  'world he',
#  'he loved',
#  'loved to',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer 
vectorizer = CountVectorizer(ngram_range=(1,1))
analyzer = vectorizer.build_analyzer()
analyzer(str(list(text1)))
# Out:
# ['moby',
#  'dick',
#  'by',
#  'herman',
#  'melville',
#  '1851',
#  'etymology',
#  'supplied',
#  'by',
#  'late',
#  'consumptive',
#  'usher',
#  'to',
#  'grammar',
#  'school',
#  'the',
#  'pale',
#  'usher',
#  'threadbare',
#  'in',
#  'coat',
#  'heart',
#  'body',
#  'and',
#  'brain',
#  'see',
#  'him',
#  'now',
#  'he',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  'with',
#  'queer',
#  'handkerchief',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  'he',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  'while',
#  'you',
#  'take',
#  'in',
#  'hand',
#  'to',
#  'school',
#  'others',
#  'and',
#  'to',
#  'teach',
#  'them',
#  'by',
#  'what',
#  'name',
#  'whale',
# ...
